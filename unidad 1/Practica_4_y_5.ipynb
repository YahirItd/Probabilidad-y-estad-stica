# %% [markdown]
# <a href="https://colab.research.google.com/github/YahirItd/Probabilidad-y-estad-stica/blob/main/unidad%201/Practica_4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tec.jpg](data:image/jpeg;base64,...)
#
# Probabilidad y Estadistica
#
# unidad 1
#
# Practica 4: Tabla de frecuencia
#
# grupo 2YY
#
# Alumno: Yahir Alexander Arreolas palacios
#
# Docente Dr.José Gabriel Rodríguez Rivas
#
# ![itd.jpg](data:image/jpeg;base64,...)

# %%
import random

# %%
edades= []
for i in range (100):
  numero_alatorio = random.randint(18,70)
  edades.append(numero_alatorio)
print(edades)
# Out:
# [59, 50, 51, 39, 27, 40, 32, 54, 59, 64, 66, 41, 69, 45, 19, 54, 70, 21, 42, 44, 25, 65, 46, 66, 18, 42, 41, 65, 28, 67, 50, 45, 38, 33, 61, 68, 68, 57, 21, 60, 52, 55, 38, 25, 44, 69, 45, 20, 23, 25, 56, 65, 52, 36, 21, 44, 49, 58, 38, 46, 60, 30, 56, 69, 49, 42, 35, 59, 19, 63, 46, 29, 57, 27, 27, 70, 44, 25, 38, 41, 55, 64, 29, 51, 58, 18, 19, 64, 69, 18, 23, 21, 50, 42, 23, 67, 35, 40, 29, 40]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades, columns=["Edad"])
df.head()
# Out:
#    Edad
# 0    59
# 1    50
# 2    51
# 3    39
# 4    27

# %%
tabla_frecuencias= df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')
print("Tabla de Distribucion de Frecuencia:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencia:
#     Edad  Frecuencia
# 12    18           3
# 7     19           3
# 35    20           1
# 4     21           4
# 8     23           3
# 1     25           4
# 15    27           3
# 39    28           1
# 17    29           3
# 40    30           1
# 33    32           1
# 36    33           1
# 21    35           2
# 38    36           1
# 0     38           4
# 37    39           1
# 16    40           3
# 18    41           3
# 3     42           4
# 2     44           4
# 13    45           3
# 10    46           3
# 23    49           2
# 9     50           3
# 25    51           2
# 28    52           2
# 19    54           2
# 26    55           2
# 24    56           2
# 20    57           2
# 22    58           2
# 6     59           3
# 27    60           2
# 34    61           1
# 41    63           1
# 14    64           3
# 11    65           3
# 31    66           2
# 30    67           2
# 32    68           2
# 5     69           4
# 29    70           2

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 12    18           3           0.03
# 7     19           3           0.03
# 35    20           1           0.01
# 4     21           4           0.04
# 8     23           3           0.03
# 1     25           4           0.04
# 15    27           3           0.03
# 39    28           1           0.01
# 17    29           3           0.03
# 40    30           1           0.01
# 33    32           1           0.01
# 36    33           1           0.01
# 21    35           2           0.02
# 38    36           1           0.01
# 0     38           4           0.04
# 37    39           1           0.01
# 16    40           3           0.03
# 18    41           3           0.03
# 3     42           4           0.04
# 2     44           4           0.04
# 13    45           3           0.03
# 10    46           3           0.03
# 23    49           2           0.02
# 9     50           3           0.03
# 25    51           2           0.02
# 28    52           2           0.02
# 19    54           2           0.02
# 26    55           2           0.02
# 24    56           2           0.02
# 20    57           2           0.02
# 22    58           2           0.02
# 6     59           3           0.03
# 27    60           2           0.02
# 34    61           1           0.01
# 41    63           1           0.01
# 14    64           3           0.03
# 11    65           3           0.03
# 31    66           2           0.02
# 30    67           2           0.02
# 32    68           2           0.02
# 5     69           4           0.04
# 29    70           2           0.02

# %%
tabla_frecuencias['Frec porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual
# 12    18           3           0.03              3.0
# 7     19           3           0.03              3.0
# 35    20           1           0.01              1.0
# 4     21           4           0.04              4.0
# 8     23           3           0.03              3.0
# 1     25           4           0.04              4.0
# 15    27           3           0.03              3.0
# 39    28           1           0.01              1.0
# 17    29           3           0.03              3.0
# 40    30           1           0.01              1.0
# 33    32           1           0.01              1.0
# 36    33           1           0.01              1.0
# 21    35           2           0.02              2.0
# 38    36           1           0.01              1.0
# 0     38           4           0.04              4.0
# 37    39           1           0.01              1.0
# 16    40           3           0.03              3.0
# 18    41           3           0.03              3.0
# 3     42           4           0.04              4.0
# 2     44           4           0.04              4.0
# 13    45           3           0.03              3.0
# 10    46           3           0.03              3.0
# 23    49           2           0.02              2.0
# 9     50           3           0.03              3.0
# 25    51           2           0.02              2.0
# 28    52           2           0.02              2.0
# 19    54           2           0.02              2.0
# 26    55           2           0.02              2.0
# 24    56           2           0.02              2.0
# 20    57           2           0.02              2.0
# 22    58           2           0.02              2.0
# 6     59           3           0.03              3.0
# 27    60           2           0.02              2.0
# 34    61           1           0.01              1.0
# 41    63           1           0.01              1.0
# 14    64           3           0.03              3.0
# 11    65           3           0.03              3.0
# 31    66           2           0.02              2.0
# 30    67           2           0.02              2.0
# 32    68           2           0.02              2.0
# 5     69           4           0.04              4.0
# 29    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual  Frec Acumulada
# 12    18           3           0.03              3.0               3
# 7     19           3           0.03              3.0               6
# 35    20           1           0.01              1.0               7
# 4     21           4           0.04              4.0              11
# 8     23           3           0.03              3.0              14
# 1     25           4           0.04              4.0              18
# 15    27           3           0.03              3.0              21
# 39    28           1           0.01              1.0              22
# 17    29           3           0.03              3.0              25
# 40    30           1           0.01              1.0              26
# 33    32           1           0.01              1.0              27
# 36    33           1           0.01              1.0              28
# 21    35           2           0.02              2.0              30
# 38    36           1           0.01              1.0              31
# 0     38           4           0.04              4.0              35
# 37    39           1           0.01              1.0              36
# 16    40           3           0.03              3.0              39
# 18    41           3           0.03              3.0              42
# 3     42           4           0.04              4.0              46
# 2     44           4           0.04              4.0              50
# 13    45           3           0.03              3.0              53
# 10    46           3           0.03              3.0              56
# 23    49           2           0.02              2.0              58
# 9     50           3           0.03              3.0              61
# 25    51           2           0.02              2.0              63
# 28    52           2           0.02              2.0              65
# 19    54           2           0.02              2.0              67
# 26    55           2           0.02              2.0              69
# 24    56           2           0.02              2.0              71
# 20    57           2           0.02              2.0              73
# 22    58           2           0.02              2.0              75
# 6     59           3           0.03              3.0              78
# 27    60           2           0.02              2.0              80
# 34    61           1           0.01              1.0              81
# 41    63           1           0.01              1.0              82
# 14    64           3           0.03              3.0              85
# 11    65           3           0.03              3.0              88
# 31    66           2           0.02              2.0              90
# 30    67           2           0.02              2.0              92
# 32    68           2           0.02              2.0              94
# 5     69           4           0.04              4.0              98
# 29    70           2           0.02              2.0             100

# %% [markdown]
# # Regla de sturges
#
# 1.   Es una regla que sirve para calcular el número de clase o intervalos idóneo en los que se debe divir un conjunto de datos
# 2.   Establece que el número de clase es igual a uno más el logaritmo en base dos del número total de datos

# %%
import math

# %%
print(edades)
# Out:
# [59, 50, 51, 39, 27, 40, 32, 54, 59, 64, 66, 41, 69, 45, 19, 54, 70, 21, 42, 44, 25, 65, 46, 66, 18, 42, 41, 65, 28, 67, 50, 45, 38, 33, 61, 68, 68, 57, 21, 60, 52, 55, 38, 25, 44, 69, 45, 20, 23, 25, 56, 65, 52, 36, 21, 44, 49, 58, 38, 46, 60, 30, 56, 69, 49, 42, 35, 59, 19, 63, 46, 29, 57, 27, 27, 70, 44, 25, 38, 41, 55, 64, 29, 51, 58, 18, 19, 64, 69, 18, 23, 21, 50, 42, 23, 67, 35, 40, 29, 40]

# %%
df=pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     59
# 1     50
# 2     51
# 3     39
# 4     27
# ..   ...
# 95    67
# 96    35
# 97    40
# 98    29
# 99    40
#
# [100 rows x 1 columns]

# %%
n= len(edades)
K= int(1+ math.log2(100))
print("Valor de n= ", n, " \nNúmero de intervalos =", K)
# Out:
# Valor de n=  100
# Número de intervalos = 7

# %%
tabla_frecuencias=pd.cut(df['Edad'], bins=K,include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['Clase','Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    19
# 1  (17.947, 25.429]    18
# 2  (40.286, 47.714]    17
# 3  (47.714, 55.143]    13
# 4  (32.857, 40.286]    12
# 5  (55.143, 62.571]    12
# 6  (25.429, 32.857]     9

# %%
tabla_frecuencias=tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    18
# 6  (25.429, 32.857]     9
# 4  (32.857, 40.286]    12
# 2  (40.286, 47.714]    17
# 3  (47.714, 55.143]    13
# 5  (55.143, 62.571]    12
# 0    (62.571, 70.0]    19

# %%
tabla_frecuencias['Frec Rel']=tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec Porc']=tabla_frecuencias['Frec']/n*100
tabla_frecuencias['Frec Ac']=tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']=tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['Frec Porc Ac']=tabla_frecuencias['Frec Porc'].cumsum()
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    18      0.18       18.0       18         0.18
# 6  (25.429, 32.857]     9      0.09        9.0       27         0.27
# 4  (32.857, 40.286]    12      0.12       12.0       39         0.39
# 2  (40.286, 47.714]    17      0.17       17.0       56         0.56
# 3  (47.714, 55.143]    13      0.13       13.0       69         0.69
# 5  (55.143, 62.571]    12      0.12       12.0       81         0.81
# 0    (62.571, 70.0]    19      0.19       19.0      100         1.00
#
#    Frec Porc Ac
# 1          18.0
# 6          27.0
# 4          39.0
# 2          56.0
# 3          69.0
# 5          81.0
# 0         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha=0.5, bins=20)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # Practica 5 Diagrama de Cajas y Bigotes

# %%
edades2= []
for i in range (100):
  numero_alatorio = random.randint(20,87)
  edades2.append(numero_alatorio)
print(edades2)
# Out:
# [87, 30, 34, 68, 27, 24, 55, 70, 21, 53, 65, 60, 41, 29, 39, 74, 23, 69, 66, 60, 53, 22, 74, 33, 30, 20, 29, 86, 51, 80, 81, 83, 72, 79, 34, 20, 85, 22, 66, 40, 21, 30, 70, 36, 37, 42, 35, 62, 49, 32, 30, 22, 41, 38, 65, 84, 21, 62, 47, 61, 34, 39, 38, 82, 41, 23, 31, 29, 71, 87, 37, 70, 74, 56, 73, 63, 26, 70, 67, 44, 24, 33, 48, 41, 83, 86, 25, 26, 68, 31, 40, 66, 73, 33, 80, 24, 64, 79, 48, 55]

# %%
fig , (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,vert=True,patch_artist=True)
ax1.set_title('Edades Encuesta 1')
bplot2=ax2.boxplot(edades2,vert=True,patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig , (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,vert=True,patch_artist=True)
ax1.set_title('Edades Encuesta 1')
bplot2=ax2.boxplot(edades2,vert=True,patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
