# %% [markdown]
# <a href="https://colab.research.google.com/github/YahirItd/Probabilidad-y-estad-stica/blob/main/unidad%201/practica_1_y_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tec.jpg](data:image/jpeg;base64,...)
#
# Probabilidad y Estadistica
#
# unidad 1
#
# Practica 1 y 2
#
# grupo 2YY
#
# Alumno: Yahir Alexander Arreolas palacios
#
# Docente Dr.José Gabriel Rodríguez Rivas
#
# ![itd.jpg](data:image/jpeg;base64,...)

# %%
from statistics import *

# %%
#Lista de calificacion del grupoo a de probabilidad y estadistica
grupoA=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoA)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# Sacar la media de las calificaciones con una formula
promedio=sum(grupoA)/len(grupoA)
print(promedio)
# Out:
# 75.33333333333333

# %%
# Utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
promedio2=mean(grupoA)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Determinar el valor de la moda con la funcion mode
moda=mode(grupoA)
print(moda)
# Out:
# 70

# %%
# Determinar el valor de la mediana con la funcion median
mediana=median(grupoA)
print(mediana)
# Out:
# 76.5

# %%
# En caso de que exista mas de una moda , se puede evaluar con multimode
moda2=multimode(grupoA)
print(moda2)
# Out:
# [70, 100]

# %%
#ejemplo 2
#definimos una variable llamda tiempo100mts de tipo lista, que contiene los tiempos que tardaron los 10 alumnos
#para correr 100m
tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print (tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("El tiempo promedio de los corredores es =>",mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es => 17.322

# %%
mediana= median(tiempos100mts)
print("El tiempo mediano de los corredores es =>",mediana)
# Out:
# El tiempo mediano de los corredores es => 17.2

# %%
moda=mode(tiempos100mts)
print("La moda de los tiempos es=>", moda)
# Out:
# La moda de los tiempos es=> 15.1

# %%
multimodas=multimode(tiempos100mts)
print("Las modas de los tiempos son =>",multimodas)
# Out:
# Las modas de los tiempos son => [15.1, 17.2]

# %%
#libreria par generar numeros aleatorios
import random

# %%
fabrica1=[]
for i in range (100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [50.56, 99.41, 61.33, 74.81, 73.06, 93.1, 60.59, 62.72, 91.21, 54.63, 98.67, 58.09, 84.67, 90.59, 87.94, 74.21, 97.2, 69.73, 94.35, 87.86, 84.79, 54.66, 73.33, 98.9, 94.5, 79.06, 87.97, 63.99, 70.35, 70.82, 84.27, 91.77, 69.83, 86.25, 87.71, 56.38, 98.05, 58.22, 70.72, 91.7, 67.31, 83.38, 73.66, 50.47, 71.83, 89.24, 61.2, 73.35, 88.62, 52.7, 53.62, 86.24, 63.23, 87.44, 78.51, 86.87, 82.92, 99.12, 98.56, 81.79, 95.7, 71.45, 85.39, 51.03, 76.47, 84.39, 87.62, 95.8, 52.07, 74.88, 78.86, 75.26, 58.01, 67.05, 70.19, 72.92, 74.32, 53.62, 63.95, 95.99, 57.79, 82.3, 53.14, 98.32, 68.21, 79.78, 83.12, 97.95, 66.36, 92.08, 84.22, 94.15, 67.06, 91.5, 50.86, 97.68, 88.89, 93.27, 56.56, 93.76]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio2=round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [50.29, 98.99, 79.5, 56.31, 59.97, 62.7, 52.4, 58.36, 68.79, 66.85, 56.53, 99.66, 84.22, 60.34, 53.55, 67.51, 91.23, 76.7, 54.77, 60.26, 52.64, 85.59, 98.18, 80.9, 77.34, 77.96, 74.98, 55.11, 53.83, 63.41, 83.72, 69.76, 58.63, 80.92, 83.26, 76.45, 58.79, 97.07, 83.92, 52.68, 83.46, 82.41, 53.06, 78.69, 63.22, 85.35, 92.93, 82.27, 62.23, 57.3, 85.88, 71.3, 77.5, 99.47, 50.81, 61.35, 86.62, 75.82, 52.26, 61.07, 81.94, 83.58, 94.9, 81.1, 75.3, 51.37, 57.69, 68.39, 52.02, 84.36, 62.17, 68.9, 66.14, 52.27, 81.62, 65.13, 94.5, 74.48, 97.42, 93.19, 58.06, 54.35, 92.99, 96.92, 51.91, 86.89, 79.22, 51.5, 75.94, 89.66, 81.23, 98.22, 86.05, 53.67, 78.64, 83.98, 91.05, 90.26, 83.68, 74.78]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("produccion diaria de la Fabrica 1 ")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la Fabrica 1 ')

# %%
plt.hist(fabrica2)
plt.title("produccion diaria de la Fabrica 2 ")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la Fabrica 2 ')

# %%
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("valores de la fabrica 1")
print("la media es ",media1)
print("la mediana es ",mediana1)
print("la moda es ",moda1)
# Out:
# valores de la fabrica 1
# la media es  77.5003
# la mediana es  78.96000000000001
# la moda es  53.62

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("valores de la fabrica 2")
print("la media es ",media2)
print("la mediana es ",mediana2)
print("la moda es ",moda2)
# Out:
# valores de la fabrica 2
# la media es  73.3254
# la mediana es  75.88
# la moda es  50.29

# %%
# generar 2 subplot de 1 renglon pr 2 columnas para desplegar los 2 histogramas, una al lado de otra
fig, (ax1, ax2)=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media1,color='b',linestyle='dashed',linewidth=2,label='Media')
plt.axvline(mediana1,color='r',linestyle='dashed',linewidth=2,label='Mediana')
plt.axvline(moda1,color='y',linestyle='dashed',linewidth=2,label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media2,color='b',linestyle='dashed',linewidth=2,label='Media')
plt.axvline(mediana2,color='r',linestyle='dashed',linewidth=2,label='Mediana')
plt.axvline(moda2,color='y',linestyle='dashed',linewidth=2,label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()
