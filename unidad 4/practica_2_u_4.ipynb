# %% [markdown]
# <a href="https://colab.research.google.com/github/YahirItd/Probabilidad-y-estad-stica/blob/main/unidad%204/practica_2_u_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tec.jpg](data:image/jpeg;base64,...)
#
# Probabilidad y Estadistica
#
# unidad 4
#
# grupo 2YY
#
# Alumno: Yahir Alexander Arreolas palacios
#
# Docente Dr.José Gabriel Rodríguez Rivas
#
# ![itd.jpg](data:image/jpeg;base64,...)

# %%
from scipy.stats import binom
probabilidad_exito = 0.83
num_pacientes = 16
X = 16
probabilidad_ninguno_enfermo = binom.pmf(X, num_pacientes, probabilidad_exito)
print("La probabilidad de que ninguno paciente sufra la enfermedad:", probabilidad_ninguno_enfermo)
# Out:
# La probabilidad de que ninguno paciente sufra la enfermedad: 0.0507282029895386

# %%
from scipy.stats import binom
probabilidad_exito = 0.83
num_pacientes = 16
X = 0
probabilidad_todos_enfermos = binom.pmf(X, num_pacientes, probabilidad_exito)
print("La probabilidad de que ninguno paciente sufra la enfermedad:", probabilidad_todos_enfermos)
# Out:
# La probabilidad de que ninguno paciente sufra la enfermedad: 4.866119187566701e-13

# %%
from scipy.stats import binom
n = 10
p = 0.10
x = 2

probabilidad_x_2 = binom.pmf(x,n,p)

print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria X sea igual a 2 es: 0.19371024450000007

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n=10
p = 0.10
valores_x = np.arange(0, n+1)
probabilidades_x = [binom.pmf(x, n, p) for x in valores_x]
print("Valores de x\Probabilidades:")
for x, probabilidad in zip(valores_x, probabilidades_x):
    print(f"{x}\t{probabilidad}")
# Out:
# Valores de x\Probabilidades:
# 0	0.34867844009999993
# 1	0.38742048899999965
# 2	0.19371024450000007
# 3	0.05739562799999998
# 4	0.01116026100000001
# 5	0.0014880347999999995
# 6	0.00013778100000000007
# 7	8.748000000000003e-06
# 8	3.6449999999999996e-07
# 9	8.999999999999995e-09
# 10	1.0000000000000006e-10

# %%
plt.figure(figsize=(8, 6))
plt.bar(valores_x, probabilidades_x, color='skyblue')
plt.title('Distribución Binomial')
plt.xlabel('Valores de x')
plt.ylabel('Probabilidad')
plt.xticks(valores_x)
plt.grid(True)
plt.show()

# %% [markdown]
# # Problema 1
# • El número x de personas ingresadas a una unidad de cuidados intensivos en un hospital particular, en un día, tiene una distribución de probabilidad de Poisson con media igual a cinco personas por día.
#
# a). ¿Cuál es la probabilidad de que el número de personas ingresadas a una unidad de cuidados intensivos en un hospital particular, en un día particular, sea dos?
#
# b). ¿Es probable que x exceda de 10? Explicar

# %%
from scipy.stats import poisson
media = 5
probabilidad_2_personas = poisson.pmf(2, media)
print("La probabilidad de que solo vayan 2 personas en el dia es de: ", probabilidad_2_personas)
probabilidad_10_personas = poisson.pmf(10, media)
print("La probabilidad de que ingresen más de 10 personas en un día es aproximadamente: ", probabilidad_10_personas, ("lo cual no es probable, ya que es un evento poco frecuente."))
# Out:
# La probabilidad de que solo vayan 2 personas en el dia es de:  0.08422433748856832
# La probabilidad de que ingresen más de 10 personas en un día es aproximadamente:  0.018132788707821854 lo cual no es probable, ya que es un evento poco frecuente.

# %% [markdown]
# # Problema 2
# • Un fabricante de podadoras para el pasto compra motores de 1 hp y 2 ciclos, en lotes de 1,000, a un proveedor.
#
# • El fabricate equipa cada una de las podadoras producidas por su planta con uno de los motores.
#
# • La historia muestra que la probabilidad de que cualquier motor del proveedor resulte no satisfactorio es.001.
#
# • En un embarque de 1,000 motores, Calcular
#
# • ¿cuál es la probabilidad de que ninguno sea defectuoso?,
#
# ¿cuál es la probabilidad de que tres sean defectuosos
#
# • ¿cuál es la probabilidad de que cuatro sean defectuoso?

# %%
from scipy.stats import poisson
print("Este es un caso típico de distribución de Poisson.")
total = 1000
probabilidad = 0.001
media = total * probabilidad
probabilidad_ninguno_defectuoso = poisson.pmf(0, media)
print("La probabilidad de que ninguna podadora sea defectuosa es: ", probabilidad_ninguno_defectuoso)
probabilidad_3_defectuoso = poisson.pmf(3, media)
print("La probabilidad de que ninguna podadora sea defectuosa es: ", probabilidad_3_defectuoso)
probabilidad_4_defectuoso = poisson.pmf(4, media)
print("La probabilidad de que ninguna podadora sea defectuosa es: ", probabilidad_4_defectuoso)
# Out:
# Este es un caso típico de distribución de Poisson.
# La probabilidad de que ninguna podadora sea defectuosa es:  0.36787944117144233
# La probabilidad de que ninguna podadora sea defectuosa es:  0.06131324019524039
# La probabilidad de que ninguna podadora sea defectuosa es:  0.015328310048810101
